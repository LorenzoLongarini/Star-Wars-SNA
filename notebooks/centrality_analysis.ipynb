# %%
#imports and load datas

import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../utils')
from define_graph import create_graphs
from centrality import make_dc, make_cc, make_bc, make_ec

G_interactions, G_mentions = create_graphs()

# %%
#degree centrality

make_dc(G_interactions)
make_dc(G_mentions)
# Out:
# Degree Centrality per le interazioni:
# ANAKIN : 0.3796296296296296
# OBI-WAN : 0.32407407407407407
# PADME : 0.3055555555555555
# C-3PO : 0.3055555555555555
# QUI-GON : 0.24074074074074073
# JAR JAR : 0.2222222222222222
# LUKE : 0.2222222222222222
# HAN : 0.21296296296296297
# EMPEROR : 0.2037037037037037
# LEIA : 0.19444444444444442
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Degree Centrality per le interazioni:
# OBI-WAN : 0.5357142857142857
# R2-D2 : 0.5357142857142857
# ANAKIN : 0.5089285714285714
# ...

# %%
#closeness centrality

make_cc(G_interactions)
make_cc(G_mentions)
# Out:
# Closeness Centrality per le interazioni:
# OBI-WAN : 0.5567010309278351
# C-3PO : 0.5538461538461539
# ANAKIN : 0.542713567839196
# LUKE : 0.5192307692307693
# HAN : 0.5094339622641509
# EMPEROR : 0.4954128440366973
# PADME : 0.4864864864864865
# DARTH VADER : 0.4864864864864865
# LEIA : 0.484304932735426
# QUI-GON : 0.47368421052631576
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Closeness Centrality per le interazioni:
# R2-D2 : 0.6746987951807228
# OBI-WAN : 0.6588235294117647
# ANAKIN : 0.6473988439306358
# C-3PO : 0.64
# ...

# %%
#betweenness centrality

make_bc(G_interactions)
make_bc(G_mentions)
# Out:
# Betwenness Centrality per le interazioni:
# OBI-WAN : 0.21687680929893424
# C-3PO : 0.196282359938358
# HAN : 0.18460259986082697
# ANAKIN : 0.16520206976527324
# LUKE : 0.14039772263781977
# DARTH VADER : 0.0896976319649676
# POE : 0.08518104645812825
# EMPEROR : 0.07572278832708307
# PADME : 0.07076777993735174
# KYLO REN : 0.05751638778332321
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Betwenness Centrality per le interazioni:
# OBI-WAN : 0.13177676434913627
# R2-D2 : 0.12155398407326098
# ANAKIN : 0.10195300988886925
# ...

# %%
#eigenvector centrality

make_ec(G_interactions)
make_ec(G_mentions)
# Out:
# Betwenness Centrality per le interazioni:
# ANAKIN : 0.3302815411844613
# OBI-WAN : 0.2968136147888759
# PADME : 0.286727301113028
# QUI-GON : 0.2557668431953123
# C-3PO : 0.25378169114445365
# EMPEROR : 0.23112543660156096
# JAR JAR : 0.22369234252463746
# YODA : 0.19543034526614914
# BAIL ORGANA : 0.18396515192464444
# MACE WINDU : 0.1679007250018132
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Betwenness Centrality per le interazioni:
# R2-D2 : 0.2506341932346775
# OBI-WAN : 0.24827735516637742
# ANAKIN : 0.23894031887275521
# ...
